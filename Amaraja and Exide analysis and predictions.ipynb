# %%
# !pip install -q yfinance

# %%
# !pip install pandas_datareader

# %%
# Import necessary libraries
from pandas_datareader import data as pdr
import yfinance as yf

# Set up Yahoo Finance integration
yf.pdr_override()

# Define a list of stock symbols
company_symbols = ['AMARAJABAT.NS', 'EXIDEIND.NS']

# Define a date range
start_date = '2023-01-01'
end_date = '2023-12-31'

# Create an empty list to store company data
company_data_list = []

# Download stock data for each company
for symbol in company_symbols:
    company_data = pdr.get_data_yahoo(symbol, start=start_date, end=end_date)
    company_data_list.append(company_data)

# Assign names to the dataframes
company_names = ["AMARAJABAT", "EXIDE"]
for data, name in zip(company_data_list, company_names):
    data["Company_Name"] = name
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-02  181.000000  181.750000  179.649994  181.399994  179.946472
# 2023-01-03  182.000000  183.000000  179.500000  180.899994  179.450470
# 2023-01-04  180.649994  181.050003  176.899994  179.199997  177.764099
# 2023-01-05  179.250000  181.550003  178.550003  180.600006  179.152893
# 2023-01-06  180.500000  181.600006  177.750000  178.399994  176.970505
# ...                ...         ...         ...         ...         ...
# 2023-09-25  256.200012  259.350006  253.600006  258.899994  258.899994
# 2023-09-26  258.899994  260.899994  256.600006  256.799988  256.799988
# 2023-09-27  257.700012  260.600006  255.350006  260.149994  260.149994
# 2023-09-28  261.100006  261.100006  256.500000  258.049988  258.049988
# 2023-09-29  259.049988  262.899994  258.549988  260.600006  260.600006
#
#              Volume Company_Name
# Date
# 2023-01-02  1333139        EXIDE
# 2023-01-03  1729484        EXIDE
# ...

# %%
data.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  185.000000  185.000000  185.000000  185.000000  185.000000
# mean   214.334865  216.640811  211.735136  214.304865  213.069022
# std     35.694360   35.933167   34.930666   35.407411   35.817067
# min    172.500000  173.800003  170.500000  172.550003  171.167389
# 25%    181.800003  183.100006  179.500000  181.449997  179.996063
# 50%    204.600006  207.000000  201.000000  205.449997  203.803757
# 75%    252.949997  255.949997  250.149994  252.100006  250.079971
# max    279.750000  279.750000  274.250000  277.450012  277.450012
#
#              Volume
# count  1.850000e+02
# mean   2.804079e+06
# std    2.638979e+06
# min    0.000000e+00
# 25%    1.486043e+06
# 50%    2.065686e+06
# 75%    3.121102e+06
# max    2.568241e+07

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 185 entries, 2023-01-02 to 2023-09-29
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          185 non-null    float64
#  1   High          185 non-null    float64
#  2   Low           185 non-null    float64
#  3   Close         185 non-null    float64
#  4   Adj Close     185 non-null    float64
#  5   Volume        185 non-null    int64
#  6   Company_Name  185 non-null    object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 11.6+ KB

# %%
for data in company_data_list:
    print(data)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-02  573.000000  577.950012  567.849976  574.799988  568.997620
# 2023-01-03  575.250000  582.799988  573.250000  575.799988  569.987549
# 2023-01-04  578.799988  578.799988  565.349976  573.150024  567.364319
# 2023-01-05  576.849976  577.750000  569.500000  575.450012  569.641113
# 2023-01-06  577.000000  589.000000  575.500000  585.900024  579.985596
# ...                ...         ...         ...         ...         ...
# 2023-09-25  639.900024  639.900024  633.000000  636.700012  636.700012
# 2023-09-26  639.000000  646.450012  635.549988  641.849976  641.849976
# 2023-09-27  641.000000  642.049988  636.500000  638.650024  638.650024
# 2023-09-28  638.700012  644.750000  635.549988  638.150024  638.150024
# 2023-09-29  638.150024  643.700012  635.549988  637.400024  637.400024
#
#              Volume Company_Name
# Date
# 2023-01-02   926003   AMARAJABAT
# 2023-01-03   595500   AMARAJABAT
# ...

# %%
company_data_list[0]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-02  573.000000  577.950012  567.849976  574.799988  568.997620
# 2023-01-03  575.250000  582.799988  573.250000  575.799988  569.987549
# 2023-01-04  578.799988  578.799988  565.349976  573.150024  567.364319
# 2023-01-05  576.849976  577.750000  569.500000  575.450012  569.641113
# 2023-01-06  577.000000  589.000000  575.500000  585.900024  579.985596
# ...                ...         ...         ...         ...         ...
# 2023-09-25  639.900024  639.900024  633.000000  636.700012  636.700012
# 2023-09-26  639.000000  646.450012  635.549988  641.849976  641.849976
# 2023-09-27  641.000000  642.049988  636.500000  638.650024  638.650024
# 2023-09-28  638.700012  644.750000  635.549988  638.150024  638.150024
# 2023-09-29  638.150024  643.700012  635.549988  637.400024  637.400024
#
#              Volume Company_Name
# Date
# 2023-01-02   926003   AMARAJABAT
# 2023-01-03   595500   AMARAJABAT
# ...

# %%
company_data_list[1]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-02  181.000000  181.750000  179.649994  181.399994  179.946472
# 2023-01-03  182.000000  183.000000  179.500000  180.899994  179.450470
# 2023-01-04  180.649994  181.050003  176.899994  179.199997  177.764099
# 2023-01-05  179.250000  181.550003  178.550003  180.600006  179.152893
# 2023-01-06  180.500000  181.600006  177.750000  178.399994  176.970505
# ...                ...         ...         ...         ...         ...
# 2023-09-25  256.200012  259.350006  253.600006  258.899994  258.899994
# 2023-09-26  258.899994  260.899994  256.600006  256.799988  256.799988
# 2023-09-27  257.700012  260.600006  255.350006  260.149994  260.149994
# 2023-09-28  261.100006  261.100006  256.500000  258.049988  258.049988
# 2023-09-29  259.049988  262.899994  258.549988  260.600006  260.600006
#
#              Volume Company_Name
# Date
# 2023-01-02  1333139        EXIDE
# 2023-01-03  1729484        EXIDE
# ...

# %%
amaraja = company_data_list[0]

# %%
amaraja.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-02  573.000000  577.950012  567.849976  574.799988  568.997620
# 2023-01-03  575.250000  582.799988  573.250000  575.799988  569.987549
# 2023-01-04  578.799988  578.799988  565.349976  573.150024  567.364319
# 2023-01-05  576.849976  577.750000  569.500000  575.450012  569.641113
# 2023-01-06  577.000000  589.000000  575.500000  585.900024  579.985596
#
#              Volume Company_Name
# Date
# 2023-01-02   926003   AMARAJABAT
# 2023-01-03   595500   AMARAJABAT
# 2023-01-04   451473   AMARAJABAT
# 2023-01-05   392215   AMARAJABAT
# 2023-01-06  1372158   AMARAJABAT

# %%
exide = company_data_list[1]

# %%
exide.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-02  181.000000  181.750000  179.649994  181.399994  179.946472
# 2023-01-03  182.000000  183.000000  179.500000  180.899994  179.450470
# 2023-01-04  180.649994  181.050003  176.899994  179.199997  177.764099
# 2023-01-05  179.250000  181.550003  178.550003  180.600006  179.152893
# 2023-01-06  180.500000  181.600006  177.750000  178.399994  176.970505
#
#              Volume Company_Name
# Date
# 2023-01-02  1333139        EXIDE
# 2023-01-03  1729484        EXIDE
# 2023-01-04  1956913        EXIDE
# 2023-01-05  1362043        EXIDE
# 2023-01-06  1453876        EXIDE

# %% [markdown]
# ## Closing Price

# %%
# Let's see a historical view of the closing price
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_data_list, 1):
    plt.subplot(2, 2, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {tech_list[i - 1]}")
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Zerodha\Technical analysis\Amaraja and Exide analysis and predictions.ipynb Cell 15 line 2
#       <a href='vscode-notebook-cell:/d%3A/Zerodha/Technical%20analysis/Amaraja%20and%20Exide%20analysis%20and%20predictions.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> # Let's see a historical view of the closing price
# ----> <a href='vscode-notebook-cell:/d%3A/Zerodha/Technical%20analysis/Amaraja%20and%20Exide%20analysis%20and%20predictions.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> plt.figure(figsize=(15, 10))
#       <a href='vscode-notebook-cell:/d%3A/Zerodha/Technical%20analysis/Amaraja%20and%20Exide%20analysis%20and%20predictions.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> plt.subplots_adjust(top=1.25, bottom=1.2)
# ...

# %% [markdown]
# ## Volume of Sales

# %%
# Now let's plot the total volume of stock being traded each day
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_data_list, 1):
    plt.subplot(2, 2, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {tech_list[i - 1]}")
    
plt.tight_layout()

# %% [markdown]
# #  What was the moving average of the various stocks?
#
# The moving average (MA) is a simple technical analysis tool that smooths out price data by creating a constantly updated average price. The average is taken over a specific period of time, like 10 days, 20 minutes, 30 weeks, or any time period the trader chooses.

# %%
ma_day = [10, 20, 50]

for ma in ma_day:
    for company in company_data_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
fig.suptitle('Stock Analysis', fontsize=16)

# Plot the first company (AMARAJA)
ax1 = amaraja[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0, 0])
ax1.set_title('AMARAJA')
ax1.set_xlabel('')
ax1.set_ylabel('Price')

# Plot the second company (EXIDE)
ax2 = exide[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0, 1])
ax2.set_title('EXIDE')
ax2.set_xlabel('')
ax2.set_ylabel('Price')

# Remove the empty subplots in the 2nd row
axes[1, 0].remove()
axes[1, 1].remove()

fig.tight_layout(rect=[0, 0, 1, 0.95])

# %% [markdown]
# ## Daily avg return on the stock

# %%
# We'll use pct_change to find the percent change for each day
for company in company_data_list:
    company['Daily Return'] = company['Adj Close'].pct_change()

# Then we'll plot the daily return percentage
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))  # Adjust nrows and figsize
fig.suptitle('Daily Returns', fontsize=16)

# Plot the first company (AMARAJA)
ax1 = amaraja['Daily Return'].plot(ax=axes[0], legend=True, linestyle='--', marker='o')
ax1.set_title('AMARAJA')
ax1.set_xlabel('')
ax1.set_ylabel('Daily Return')

# Plot the second company (EXIDE)
ax2 = exide['Daily Return'].plot(ax=axes[1], legend=True, linestyle='--', marker='o')
ax2.set_title('EXIDE')
ax2.set_xlabel('')
ax2.set_ylabel('Daily Return')

fig.tight_layout(rect=[0, 0, 1, 0.85])

# %%
plt.figure(figsize=(12, 9))

for i, company in enumerate(company_data_list, 1):
    plt.subplot(2, 2, i)
    company['Daily Return'].hist(bins=50)
    plt.xlabel('Daily Return')
    plt.ylabel('Counts')
    plt.title(f'{company_name[i - 1]}')
    
plt.tight_layout()

# %% [markdown]
# #  What was the correlation between different stocks closing prices?

# %%
# Grab all the closing prices for the tech stock list into one DataFrame

closing_df = pdr.get_data_yahoo(tech_list, start=start, end=end)['Adj Close']

# Make a new tech returns DataFrame
tech_rets = closing_df.pct_change()
tech_rets.head()
# Out:
# [*********************100%%**********************]  2 of 2 completed
#             AMARAJABAT.NS  EXIDEIND.NS
# Date
# 2022-09-30            NaN          NaN
# 2022-10-03      -0.019756    -0.020707
# 2022-10-04       0.027322     0.018217
# 2022-10-06       0.013348     0.007668
# 2022-10-07      -0.000299    -0.003171

# %%
sns.pairplot(tech_rets, kind='reg')

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
sns.heatmap(tech_rets.corr(), annot=True, cmap='summer')
plt.title('Correlation of stock return')

plt.subplot(2, 2, 2)
sns.heatmap(closing_df.corr(), annot=True, cmap='summer')
plt.title('Correlation of stock closing price')
# Out:
# Text(0.5, 1.0, 'Correlation of stock closing price')

# %% [markdown]
# #  How much value do we put at risk by investing in a particular stock?

# %%
rets = tech_rets.dropna()

area = np.pi * 20

plt.figure(figsize=(10, 8))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='-', color='blue', connectionstyle='arc3,rad=-0.3'))

# %% [markdown]
# #  Predicting the closing price stock price of AMARAJA :

# %%
# Get the stock quote
df = pdr.get_data_yahoo('AMARAJABAT.NS', start='2019-01-01', end=datetime.now())
# Show teh data
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2019-01-01  742.849976  746.700012  736.000000  738.799988  694.067078  189588
# 2019-01-02  740.000000  741.099976  730.799988  733.549988  689.135010  265053
# 2019-01-03  731.750000  734.349976  710.150024  716.000000  672.647522  372293
# 2019-01-04  718.250000  727.500000  716.000000  723.650024  679.834412  389940
# 2019-01-07  722.000000  743.299988  722.000000  735.549988  691.013855  351507
# ...                ...         ...         ...         ...         ...     ...
# 2023-09-25  639.900024  639.900024  633.000000  636.700012  636.700012  197306
# 2023-09-26  639.000000  646.450012  635.549988  641.849976  641.849976  290636
# 2023-09-27  641.000000  642.049988  636.500000  638.650024  638.650024  191185
# 2023-09-28  638.700012  644.750000  635.549988  638.150024  638.150024  188953
# ...

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Create a new dataframe with only the 'Close column 
data = df.filter(['Close'])
# Convert the dataframe to a numpy array
dataset = data.values
# Get the number of rows to train the model on
training_data_len = int(np.ceil( len(dataset) * .95 ))

training_data_len
# Out:
# 1117

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.56605112],
#        [0.55776514],
#        [0.53006629],
#        ...,
#        [0.40798616],
#        [0.40719701],
#        [0.4060133 ]])

# %%
# Create the training data set 
# Create the scaled training data set
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# x_train.shape
# Out:
# [array([0.56605112, 0.55776514, 0.53006629, 0.54214019, 0.5609217 ,
#        0.56589333, 0.56912879, 0.59177711, 0.59232957, 0.60353534,
#        0.6080335 , 0.61071651, 0.63928348, 0.63431185, 0.62586808,
#        0.63312814, 0.6349432 , 0.62539461, 0.61000636, 0.56826076,
#        0.58751583, 0.5865688 , 0.5757576 , 0.61466221, 0.61845013,
#        0.61647728, 0.63644259, 0.63581124, 0.58862055, 0.56865533,
#        0.56833965, 0.56731373, 0.56865533, 0.57110165, 0.56526198,
#        0.54316602, 0.56029045, 0.55239903, 0.55547661, 0.55058397,
#        0.53851007, 0.53148679, 0.54726961, 0.56052713, 0.57907195,
#        0.57204858, 0.56589333, 0.57599428, 0.57875628, 0.58467484,
#        0.57820392, 0.57828281, 0.55847538, 0.56833965, 0.5475063 ,
#        0.53022408, 0.51665089, 0.52012313, 0.53858906, 0.53235482])]
# [0.5389046376266419]
#
# [array([0.56605112, 0.55776514, 0.53006629, 0.54214019, 0.5609217 ,
#        0.56589333, 0.56912879, 0.59177711, 0.59232957, 0.60353534,
# ...

# %%
# !pip install keras

# %%
# !pip install tensorflow

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# 1057/1057 [==============================] - 17s 14ms/step - loss: 0.0028

# %%
# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002 
test_data = scaled_data[training_data_len - 60: , :]
# Create the data sets x_test and y_test
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    
# Convert the data to a numpy array
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Get the models predicted price values 
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
F
# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse
# Out:
# 2/2 [==============================] - 0s 21ms/step
# 13.432757805516555

# %%
# Plot the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24584\2388977846.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
# Show the valid and predicted prices
valid
# Out:
#                  Close  Predictions
# Date
# 2023-07-10  693.049988   692.802551
# 2023-07-11  679.450012   694.084656
# 2023-07-12  699.750000   689.421143
# 2023-07-13  687.700012   688.402527
# 2023-07-14  684.650024   686.135925
# 2023-07-17  685.000000   683.152588
# 2023-07-18  642.799988   680.706177
# 2023-07-19  644.750000   668.181030
# 2023-07-20  612.299988   654.643372
# 2023-07-21  624.150024   635.648560
# 2023-07-24  625.049988   621.869385
# 2023-07-25  627.900024   614.223572
# 2023-07-26  632.900024   612.285706
# 2023-07-27  631.900024   614.992737
# 2023-07-28  624.400024   619.142822
# 2023-07-31  634.849976   621.124512
# 2023-08-01  641.450012   624.190369
# 2023-08-02  634.650024   628.632446
# 2023-08-03  624.750000   630.870789
# 2023-08-04  626.150024   628.916931
# 2023-08-07  626.700012   625.680908
# 2023-08-08  625.549988   622.661743
# 2023-08-09  624.450012   620.152161
# 2023-08-10  623.950012   618.212036
# 2023-08-11  617.750000   616.895325
# ...

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# Determine the number of future rows to add
num_future_rows = 30  # Adjust this as needed

# Generate future dates starting from the last date in your dataset
last_date = df.index[-1]  # Assuming the DataFrame has a DatetimeIndex
future_dates = [last_date + timedelta(days=i) for i in range(1, num_future_rows + 1)]

# Create a DataFrame with the future dates
future_df = pd.DataFrame(index=future_dates)

# Assuming 'predictions' contains the model's predictions for future 'Close' values
# If not, you can replace 'predictions' with the appropriate values
future_close_values = predictions[-num_future_rows:]  # Adjust this as needed

# Create a DataFrame with the future 'Close' values
future_df['Close'] = future_close_values

# Concatenate the 'future_df' with the original 'df' to add future rows
valid_with_future = pd.concat([df, future_df])

# 'valid_with_future' now contains the original data along with the additional rows for future dates and 'Close' values.

# %%
valid_with_future.tail(50)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2023-09-01  629.799988  631.799988  625.000000  625.549988  625.549988
# 2023-09-04  628.750000  629.599976  623.849976  624.849976  624.849976
# 2023-09-05  627.549988  651.750000  625.000000  649.950012  649.950012
# 2023-09-06  653.000000  667.099976  652.500000  656.349976  656.349976
# 2023-09-07  661.450012  664.299988  656.250000  661.200012  661.200012
# 2023-09-08  662.950012  674.000000  654.000000  656.200012  656.200012
# 2023-09-11  666.799988  666.799988  656.250000  660.000000  660.000000
# 2023-09-12  667.849976  671.799988  643.099976  654.099976  654.099976
# 2023-09-13  649.500000  659.599976  638.000000  647.200012  647.200012
# 2023-09-14  653.250000  656.650024  646.049988  648.299988  648.299988
# 2023-09-15  654.799988  654.799988  647.049988  649.000000  649.000000
# 2023-09-18  652.299988  658.000000  648.799988  650.150024  650.150024
# ...
